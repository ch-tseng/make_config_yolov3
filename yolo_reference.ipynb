# %% [markdown]
# <a href="https://colab.research.google.com/github/ch-tseng/make_config_yolov3/blob/master/yolo_reference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ln -s "/content/gdrive/My Drive" /mydrive

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %cd /mydrive/
# !wget "https://img3.secretchina.com/pic/2020/1-27/p2612861a168483659-ss.jpg"
# Out:
# /content/gdrive/My Drive
# --2020-02-17 06:58:03--  https://img3.secretchina.com/pic/2020/1-27/p2612861a168483659-ss.jpg
# Resolving img3.secretchina.com (img3.secretchina.com)... 104.20.35.78, 104.20.34.78, 2606:4700:10::6814:224e, ...
# Connecting to img3.secretchina.com (img3.secretchina.com)|104.20.35.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53610 (52K) [image/jpeg]
# Saving to: ‘p2612861a168483659-ss.jpg’
#
# p2612861a168483659- 100%[===================>]  52.35K  --.-KB/s    in 0.004s
#
# 2020-02-17 06:58:03 (14.2 MB/s) - ‘p2612861a168483659-ss.jpg’ saved [53610/53610]

# %%
# %cd "/mydrive/space_Colab/darknet/"
# !chmod 755 ./darknet
# !./darknet detector test \
    /mydrive/space_Colab/training/yolo_config/obj_colab.data \
    /mydrive/space_Colab/training/yolo_config/yolov3-tiny.cfg \
    /mydrive/space_Colab/training/yolo_config/weights/yolov3-tiny_63000.weights \
    /mydrive/p2612861a168483659-ss.jpg -dont_show
# Out:
# /content/gdrive/My Drive/space_Colab/darknet
#  CUDA-version: 10000 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %%
img = cv2.imread("/mydrive/space_Colab/darknet/predictions.jpg")
# %matplotlib inline

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
